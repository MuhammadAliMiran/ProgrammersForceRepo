# %%
import pandas as pd
import numpy as np

# %%
data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
        'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
        'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}

labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %% [markdown]
# Create a DataFrame df from this dictionary data which has the index labels.

# %%
df = pd.DataFrame(data,index=labels)
print(df)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  2.0       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# Display a summary of the basic information about this DataFrame and its data (hint: there is a single method that can be called on the DataFrame).

# %%
df.describe()
# Out:
#             age     visits
# count  8.000000  10.000000
# mean   3.437500   1.900000
# std    2.007797   0.875595
# min    0.500000   1.000000
# 25%    2.375000   1.000000
# 50%    3.000000   2.000000
# 75%    4.625000   2.750000
# max    7.000000   3.000000

# %% [markdown]
# Return the first 3 rows of the DataFrame df.

# %%
df.head(3)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no

# %% [markdown]
# Select just the 'animal' and 'age' columns from the DataFrame df.

# %%
df[['animal','age']]
# Out:
#   animal  age
# a    cat  2.5
# b    cat  3.0
# c  snake  0.5
# d    dog  NaN
# e    dog  5.0
# f    cat  2.0
# g  snake  4.5
# h    cat  NaN
# i    dog  7.0
# j    dog  3.0

# %% [markdown]
# Select the data in rows [3, 4, 8] and in columns ['animal', 'age'].

# %%
df.loc[['d', 'e', 'i'], ['animal', 'age']]
# Out:
#   animal  age
# d    dog  NaN
# e    dog  5.0
# i    dog  7.0

# %% [markdown]
# Select only the rows where the number of visits is greater than 3

# %%
df[df["visits"]>3]
# Out:
# Empty DataFrame
# Columns: [animal, age, visits, priority]
# Index: []

# %% [markdown]
# Select the rows where the age is missing, i.e. it is NaN.

# %%
df[df['age'].isnull()]
# Out:
#   animal  age  visits priority
# d    dog  NaN       3      yes
# h    cat  NaN       1      yes

# %% [markdown]
# Select the rows where the animal is a cat and the age is less than 3.

# %%
df[(df['animal']=='cat') & (df['age'] < 3)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# f    cat  2.0       3       no

# %% [markdown]
# Select the rows the age is between 2 and 4 (inclusive).

# %%
df[(df['age'] >= 2) & (df['age'] <= 4)]
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# f    cat  2.0       3       no
# j    dog  3.0       1       no

# %% [markdown]
# Change the age in row 'f' to 1.5.

# %%
df.loc['f', 'age'] = 1.5
df
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no

# %% [markdown]
# Calculate the sum of all visits in df (i.e. find the total number of visits).

# %%
df['visits'].sum()
# Out:
# 19

# %% [markdown]
# Calculate the mean age for each different animal in df.

# %%
df.groupby('animal')['age'].mean()
# Out:
# animal
# cat      2.333333
# dog      5.000000
# snake    2.500000
# Name: age, dtype: float64

# %% [markdown]
# Append a new row 'k' to df with your choice of values for each column. Then delete that row to return the original DataFrame

# %%
print(df)
new_row = pd.DataFrame({'animal': ['elephant'], 'age': [10], 'visits': [4], 'priority': ['yes']})
new_row.index = ['k']

df.append(new_row)
# Out:
#   animal  age  visits priority
# a    cat  2.5       1      yes
# b    cat  3.0       3      yes
# c  snake  0.5       2       no
# d    dog  NaN       3      yes
# e    dog  5.0       2       no
# f    cat  1.5       3       no
# g  snake  4.5       1       no
# h    cat  NaN       1      yes
# i    dog  7.0       2       no
# j    dog  3.0       1       no
# <ipython-input-15-5ddb3f948b84>:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df.append(new_row)
#      animal   age  visits priority
# a       cat   2.5       1      yes
# b       cat   3.0       3      yes
# c     snake   0.5       2       no
# d       dog   NaN       3      yes
# e       dog   5.0       2       no
# f       cat   1.5       3       no
# g     snake   4.5       1       no
# h       cat   NaN       1      yes
# i       dog   7.0       2       no
# j       dog   3.0       1       no
# k  elephant  10.0       4      yes

# %% [markdown]
# Count the number of each type of animal in df.

# %%
df['animal'].value_counts()
# Out:
# cat      4
# dog      4
# snake    2
# Name: animal, dtype: int64

# %% [markdown]
# Sort df first by the values in the 'age' in decending order, then by the value in the 'visits' column in ascending order (so row i should be first, and row d should be last).

# %%
df.sort_values(by=['age','visits'],ascending=[False,True])
# Out:
#   animal  age  visits priority
# i    dog  7.0       2       no
# e    dog  5.0       2       no
# g  snake  4.5       1       no
# j    dog  3.0       1       no
# b    cat  3.0       3      yes
# a    cat  2.5       1      yes
# f    cat  1.5       3       no
# c  snake  0.5       2       no
# h    cat  NaN       1      yes
# d    dog  NaN       3      yes

# %% [markdown]
# The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be True and 'no' should be False.

# %%
df['priority'] = df['priority'].replace({'yes': True, 'no': False})
df
# Out:
#   animal  age  visits  priority
# a    cat  2.5       1      True
# b    cat  3.0       3      True
# c  snake  0.5       2     False
# d    dog  NaN       3      True
# e    dog  5.0       2     False
# f    cat  1.5       3     False
# g  snake  4.5       1     False
# h    cat  NaN       1      True
# i    dog  7.0       2     False
# j    dog  3.0       1     False

# %% [markdown]
# In the 'animal' column, change the 'snake' entries to 'python'.

# %%
df['animal'] = df['animal'].replace({'snake': 'python'})
df
# Out:
#    animal  age  visits  priority
# a     cat  2.5       1      True
# b     cat  3.0       3      True
# c  python  0.5       2     False
# d     dog  NaN       3      True
# e     dog  5.0       2     False
# f     cat  1.5       3     False
# g  python  4.5       1     False
# h     cat  NaN       1      True
# i     dog  7.0       2     False
# j     dog  3.0       1     False

# %% [markdown]
# For each animal type and each number of visits, find the mean age. In other words, each row is an animal, each column is a number of visits and the values are the mean ages (hint: use a pivot table).

# %%
df.pivot_table(index='animal', columns='visits', values='age', aggfunc='mean')
# Out:
# visits    1    2     3
# animal
# cat     2.5  NaN  2.25
# dog     3.0  6.0   NaN
# python  4.5  0.5   NaN

# %% [markdown]
# You have a DataFrame df with a column 'A' of integers. For example:

# %%
df = pd.DataFrame({'A': [1, 2, 2, 3, 4, 5, 5, 5, 6, 7, 7]})

# %% [markdown]
# How do you filter out rows which contain the same integer as the row immediately above?
#
# You should be left with a column containing the following values:

# %%
df[df['A'] != df['A'].shift(1)]
# Out:
#    A
# 0  1
# 1  2
# 3  3
# 4  4
# 5  5
# 8  6
# 9  7

# %% [markdown]
# Given a DataFrame of numeric values, say

# %%
df = pd.DataFrame(np.random.random(size=(5, 3))) # a 5x3 frame of float values
df
# Out:
#           0         1         2
# 0  0.306995  0.417774  0.595824
# 1  0.160388  0.755983  0.538286
# 2  0.720969  0.453260  0.983363
# 3  0.269278  0.580773  0.587574
# 4  0.747397  0.151946  0.926401

# %% [markdown]
# how do you subtract the row mean from each element in the row?

# %%
df_subtracted = df.sub(df.mean(axis=1), axis=0)
df_subtracted
# Out:
#           0         1         2
# 0 -0.133203 -0.022424  0.155626
# 1 -0.324498  0.271098  0.053400
# 2  0.001772 -0.265937  0.264165
# 3 -0.209930  0.101564  0.108366
# 4  0.138815 -0.456635  0.317820

# %% [markdown]
# Suppose you have DataFrame with 10 columns of real numbers, for example:

# %%
df = pd.DataFrame(np.random.random(size=(5, 10)), columns=list('abcdefghij'))
df
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.765649  0.935435  0.265205  0.166412  0.160573  0.522773  0.283100
# 1  0.703593  0.110657  0.805566  0.872547  0.721263  0.441420  0.999516
# 2  0.391672  0.171450  0.921795  0.754382  0.773369  0.139807  0.888771
# 3  0.119494  0.731527  0.363525  0.074969  0.918658  0.723595  0.555050
# 4  0.754144  0.711692  0.149467  0.024039  0.157097  0.200970  0.979188
#
#           h         i         j
# 0  0.047569  0.126307  0.426129
# 1  0.808487  0.320833  0.761543
# 2  0.673747  0.126911  0.315883
# 3  0.904612  0.609909  0.499888
# 4  0.433975  0.645899  0.830236

# %% [markdown]
# Which column of numbers has the smallest sum? Return that column's label.

# %%
df.sum().idxmin()
# Out:
# 'i'

# %% [markdown]
# How do you count how many unique rows a DataFrame has (i.e. ignore all rows that are duplicates)? As input, use a DataFrame of zeros and ones with 10 rows and 3 columns.

# %%
df = pd.DataFrame(np.random.randint(0, 2, size=(10, 3)))
df
print(df.drop_duplicates())
df.shape[0]
# Out:
#    0  1  2
# 0  1  0  0
# 1  1  1  1
# 2  0  0  1
# 3  1  1  0
# 5  0  1  1
# 6  0  0  0
# 10

# %% [markdown]
#  A DataFrame has a column of groups 'grps' and and column of integer values 'vals':

# %% [markdown]
# For each group, find the sum of the three greatest values. You should end up with the answer as follows:
#
# grps
# a    409
# b    156
# c    345

# %%
df = pd.DataFrame({'grps': list('aaabbcaabcccbbc'),
                   'vals': [12,345,3,1,45,14,4,52,54,23,235,21,57,3,87]})

# write a solution to the question here
result = df.groupby('grps')['vals'].nlargest(3).sum(level=0)
result
# Out:
# <ipython-input-48-7d2eb9fa0dce>:5: FutureWarning: Using the level keyword in DataFrame and Series aggregations is deprecated and will be removed in a future version. Use groupby instead. df.sum(level=1) should use df.groupby(level=1).sum().
#   result = df.groupby('grps')['vals'].nlargest(3).sum(level=0)
# grps
# a    409
# b    156
# c    345
# Name: vals, dtype: int64
